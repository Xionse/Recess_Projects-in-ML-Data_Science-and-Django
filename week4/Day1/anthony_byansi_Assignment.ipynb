# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Loading our Datasets

# %%
df1 = pd.read_csv("/content/2018CrimeStatisticsByCategoryOfCrime.csv")
# df2 = pd.read_csv("/content/MPsProfileInformation10thParliament.csv")
df3 = pd.read_csv("/content/UceResultsBySchool2011-2016.csv")

# %%
df1.head(3)
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  \
# 0                     NaN                    NaN              NaN
# 1  Cases with convictions  Cases with Acquittals  Cases Dismissed
# 2                       6                      7                8
#
#               Unnamed: 10 PERSONS TAKEN TO COURT  Unnamed: 12   Unnamed: 13  \
# ...

# %% [markdown]
# ## Column mapping Technique: Renaming the coumns to the appropriate formats
#
#         for better reability

# %%
import pandas as pd

# Creating my dictionary for column mapping
column_mapping = {
    'Unnamed: 0': 'Case_ID',
    'Unnamed: 1': 'Offense_Type',
    'REPORTED CASES': 'Offense_Date',
    'Unnamed: 3': 'Offense_Location',
    'Unnamed: 4': 'Arrest_Date',
    'Unnamed: 5': 'Arresting_Officer',
    'PERFOMANCE': 'Suspect_Name',
    'Unnamed: 7': 'Suspect_Age',
    'Unnamed: 8': 'Suspect_Gender',
    'Unnamed: 9': 'Victim_Name',
    'Unnamed: 10': 'Victim_Age',
    'PERSONS TAKEN TO COURT': 'Victim_Gender',
    'Unnamed: 12': 'Crime_Description',
    'Unnamed: 13': 'Case_Status',
    'Unnamed: 14': 'Court_Date',
    'Unnamed: 15': 'Sentencing_Date',
    'Unnamed: 16': 'Prison_Term',
    'Unnamed: 17': 'Fine_Amount',
    'Unnamed: 18': 'Probation_Period',
    'Unnamed: 19': 'Appeals',
    'Unnamed: 20': 'Conviction',
    'Unnamed: 21': 'Evidence',
    'SENTENCES IMPOSED BY COURTS': 'Witnesses',
    'Unnamed: 23': 'Investigating_Officer',
    'Unnamed: 24': 'Case_Category',
    'Unnamed: 25': 'Juvenile_Offender',
    'Unnamed: 26': 'Weapon_Used',
    'Unnamed: 27': 'Motive',
    'Unnamed: 28': 'Previous_Offenses',
    'Unnamed: 29': 'Arresting_Agency',
    'Unnamed: 30': 'Column30',
    'Unnamed: 31': 'Column31',
    'Unnamed: 32': 'Column32',
    'Unnamed: 33': 'Column33',
    'Unnamed: 34': 'Column34',
    'Unnamed: 35': 'Column35',
    'Unnamed: 36': 'Column36',
    'Unnamed: 37': 'Column37'
}

df = pd.read_csv('/content/2018CrimeStatisticsByCategoryOfCrime.csv')
df = df.rename(columns=column_mapping)

df.head()
# Out:
#   Case_ID           Offense_Type  Offense_Date     Offense_Location  \
# 0     NaN                    NaN           NaN                  NaN
# 1     NaN                    NaN  Totals Cases  Cases under Inquiry
# 2   S/No.  CASE/CRIME INCIDENCES             1                    2
# 3     NaN              HOMICIDES           NaN                  NaN
# 4       1   Death  (by shooting)           190                  117
#
#         Arrest_Date     Arresting_Officer               Suspect_Name  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#               Suspect_Age         Suspect_Gender      Victim_Name  \
# 0                     NaN                    NaN              NaN
# ...

# %%
# Droping my columns with the missing values

df.dropna(axis=1)
# df = df.dropna(axis='columns'): This one is a bit tricky and deadly as it drops all columns suppose that have any missing value
df.head() # After runnig the above, I lost my data and that was the end 😒👆👆👆
# Out:
#   Case_ID           Offense_Type  Offense_Date     Offense_Location  \
# 0     NaN                    NaN           NaN                  NaN
# 1     NaN                    NaN  Totals Cases  Cases under Inquiry
# 2   S/No.  CASE/CRIME INCIDENCES             1                    2
# 3     NaN              HOMICIDES           NaN                  NaN
# 4       1   Death  (by shooting)           190                  117
#
#         Arrest_Date     Arresting_Officer               Suspect_Name  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#               Suspect_Age         Suspect_Gender      Victim_Name  \
# 0                     NaN                    NaN              NaN
# ...

# %% [markdown]
# # Visualising my columns

# %%
for column in df.columns:
    #appropriate visualization based on column type
    if df[column].dtype == 'object':  # Categorical column
        plt.figure(figsize=(8, 6))
        sns.countplot(data=df, x=column)
        plt.title(f'{column} Distribution')
        plt.xticks(rotation=45)
        plt.show()
    elif df[column].dtype == 'int64' or df[column].dtype == 'float64':  # Numeric column
        plt.figure(figsize=(8, 6))
        sns.histplot(data=df, x=column, kde=True)
        plt.title(f'{column} Distribution')
        plt.show()
    else:  # Other column typ

        pass

# %%
df3.describe()
# Out:
#                YEAR  TOTAL CANDIDATES   TOTAL DIV 1       % DIV 1  \
# count  17639.000000      17368.000000  12858.000000  17639.000000
# mean    2013.582119        100.111469     10.348266      6.226481
# std        1.710821         66.964610     26.214334     13.266156
# min     2011.000000          1.000000      0.000000      0.000000
# 25%     2012.000000         54.000000      1.000000      0.000000
# 50%     2014.000000         84.000000      3.000000      1.800000
# 75%     2015.000000        128.000000      8.000000      5.700000
# max     2016.000000        499.000000    430.000000    100.000000
#
#         TOTAL DIV 2       % DIV 2   TOTAL DIV 3       % DIV 3   TOTAL DIV 4  \
# count  16880.000000  17639.000000  17168.000000  17639.000000  16888.000000
# mean      16.058649     14.748733     22.545841     22.165344     45.981348
# std       19.324105     12.800108     17.804404     10.241613     35.558741
# ...

# %%
df3

## Bruh 😢😢😢😢 🤦‍♂️🤦‍♂️🤌🎧 This dataset is really huge, my i5 desktop is crashing coz of this
